# %% [markdown]
# # Trigonometric Functions

# %%
import numpy as np

# %% [markdown]
# ## Basic Trigonometric Functions

# %%
# sin, cos, tan
result = np.sin(np.pi/2)
print("sin(π/2):", result)

# Hyperbolic functions
print("sinh(π/2):", np.sinh(np.pi/2))
print("cosh, tanh are also available")
# Out:
# sin(π/2): 1.0
# sinh(π/2): 2.3012989023072947
# cosh, tanh are also available

# %% [markdown]
# ## Inverse Trigonometric Functions

# %%
# arcsin returns radians
x = np.arcsin(1)
print("arcsin(1) in radians:", x)

# Convert to degrees
y = np.degrees(x)
print("Converted to degrees:", y)

# Convert to radians
z = np.radians(90)
print("90 degrees in radians:", z)
# Out:
# arcsin(1) in radians: 1.5707963267948966
# Converted to degrees: 90.0
# 90 degrees in radians: 1.5707963267948966

# %% [markdown]
# ## Degree and Radian Conversion

# %%
# Degrees to radians
arr = np.array([90, 180, 270, 360])
print("Degrees:", arr)
x = np.deg2rad(arr)
print("In radians:", x)

# Radians to degrees
arr = np.array([np.pi/2, np.pi/3, np.pi/4])
print("\nRadians:", arr)
print("In degrees:", np.rad2deg(arr))
# Out:
# Degrees: [ 90 180 270 360]
# In radians: [1.57079633 3.14159265 4.71238898 6.28318531]
#
# Radians: [1.57079633 1.04719755 0.78539816]
# In degrees: [90. 60. 45.]

# %% [markdown]
# ## Finding Angles

# %%
# arcsin for single value
x = np.arcsin(1)
print("arcsin(1):", x)
print("arcsinh(1):", np.arcsinh(1))
# Out:
# arcsin(1): 1.5707963267948966
# arcsinh(1): 0.881373587019543

# %%
# arcsin for array
arr = np.array([-1, 0, 1])
print("Array:", arr)
print("arcsin:", np.arcsin(arr))
print("arccos and arctan also available")
# Out:
# Array: [-1  0  1]
# arcsin: [-1.57079633  0.          1.57079633]
# arccos and arctan also available

# %% [markdown]
# ## Pythagorean Theorem

# %%
# Calculate hypotenuse
base = 3
height = 4
hyp = np.hypot(base, height)
print(f"Hypotenuse of {base}-{height} triangle:", hyp)
# Out:
# Hypotenuse of 3-4 triangle: 5.0
